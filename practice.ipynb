# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
arr = np.array([[1,0,1],[0,1,0],[1,0,1]])

# %%
plt.imshow(arr)

# %%
arr2 = np.zeros((8,8), dtype = int)
for i in range(len(arr2)):
    for j in range(len(arr2)):
        if (i+j)%2 == 0:
            arr2[i][j] = 1

# %%
plt.imshow(arr2)

# %%
img = []
for i in range(1080):
  temp = []
  for j in range(1920):
    temp.append(0)
  img.append(temp)

# %%
plt.imshow(img)

# %%
arr = np.array([[[ 255,0,0 ] , [ 255,0,0 ] ,[ 255,0,0 ]],
                [[ 0,255,0 ] , [ 0,255,0 ] ,[ 0,255,0 ]],
                [[ 0,0,255 ] , [ 0,0,255 ] ,[ 0,0,255 ]]])
plt.imshow(arr)

# %%
plt.imshow(np.array([[[30,0,0],[150,0,0],[255,0,0]],
                     [[0,30,0],[0,150,0],[0,255,0]],
                     [[0,0,30],[0,0,150],[0,0,255]]]))

# %%
img = []
for i in range(256):
  temp = []
  for j in range(1536):
    temp.append([i,0,0])
  img.append(temp)


for i in range(256,0,-1):
  temp = []
  for j in range(1536):
    temp.append([i,0,0])
  img.append(temp)



for i in range(256):
  temp = []
  for j in range(1536):
    temp.append([0,i,0])
  img.append(temp)

for i in range(256,0,-1):
  temp = []
  for j in range(1536):
    temp.append([0,i,0])
  img.append(temp)


for i in range(256):
  temp = []
  for j in range(1536):
    temp.append([0,0,i])
  img.append(temp)

for i in range(256,0,-1):
  temp = []
  for j in range(1536):
    temp.append([0,0,i])
  img.append(temp)

plt.imshow(img)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0..256].
